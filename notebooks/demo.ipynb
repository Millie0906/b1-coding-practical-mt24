# %%
# Add relevant Jupyter notebook extensions 
# %load_ext autoreload
# %autoreload 2

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['C:\\Users\\ameli\\OneDrive\\Year 3\\B1\\python313.zip', 'C:\\Users\\ameli\\OneDrive\\Year 3\\B1\\DLLs', 'C:\\Users\\ameli\\OneDrive\\Year 3\\B1\\Lib', 'C:\\Users\\ameli\\OneDrive\\Year 3\\B1', 'c:\\Users\\ameli\\OneDrive\\Year 3\\B1\\first-venv', '', 'c:\\Users\\ameli\\OneDrive\\Year 3\\B1\\first-venv\\Lib\\site-packages', 'C:\\Users\\ameli\\OneDrive\\Year 3\\B1\\b1-coding-practical-mt24', 'c:\\Users\\ameli\\OneDrive\\Year 3\\B1\\first-venv\\Lib\\site-packages\\win32', 'c:\\Users\\ameli\\OneDrive\\Year 3\\B1\\first-venv\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\ameli\\OneDrive\\Year 3\\B1\\first-venv\\Lib\\site-packages\\Pythonwin']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from uuv_mission.dynamic import Submarine
from uuv_mission.dynamic import ClosedLoop
from uuv_mission.control import Controller
from uuv_mission.dynamic import Mission

# %%
sub = Submarine()
# Instantiate your controller (depending on your implementation)
controller = Controller(Kp=0.15, Kd=0.6)
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv(r"C:\Users\ameli\OneDrive\Year 3\B1\b1-coding-practical-mt24\data\mission.csv") # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
